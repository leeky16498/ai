# %%
import os
import tensorflow as tf 
from tensorflow.keras.layers import *
from tensorflow.keras import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator 

import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 

plt.style.use('seaborn')
# Out:
# C:\Users\leeky\AppData\Local\Temp\ipykernel_24124\2419346892.py:11: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
train_dir = "C:\\Users\\leeky\\Desktop\\tomato\\train"
test_dir = "C:\\Users\\leeky\\Desktop\\tomato\\test"

# %%
train_weather_fnames = os.listdir(train_dir)
train_weather_fnames
# Out:
# ['Tomato___Bacterial_spot',
#  'Tomato___Early_blight',
#  'Tomato___healthy',
#  'Tomato___Late_blight',
#  'Tomato___Leaf_Mold',
#  'Tomato___Septoria_leaf_spot',
#  'Tomato___Spider_mites Two-spotted_spider_mite',
#  'Tomato___Target_Spot',
#  'Tomato___Tomato_mosaic_virus',
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus']

# %%
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    shear_range = 0.2,
    horizontal_flip = True,
    validation_split=0.2
)

test_datagen = ImageDataGenerator(
    rescale = 1./255,
)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir, target_size=(150,150), batch_size=16, class_mode='categorical', shuffle=True, subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    train_dir, target_size=(150,150), batch_size=16, class_mode='categorical', shuffle=True, subset='validation'
)

test_generator = test_datagen.flow_from_directory(
    test_dir, target_size=(150,150), batch_size=16, class_mode='categorical', shuffle=False
)
# Out:
# Found 8000 images belonging to 10 classes.
# Found 2000 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.

# %%
img = train_generator[0]
print(img[0].shape)
print(img[1].shape)
# Out:
# (16, 150, 150, 3)
# (16, 10)

# %%
labels = [k for k in train_generator.class_indices]
sample_generate = train_generator.__next__()

images = sample_generate[0]
titles = sample_generate[1]

plt.figure(figsize = (20 ,20))

for i in range(15):
    plt.subplot(5 , 5, i+1)
    plt.subplots_adjust(hspace = 0.7, wspace = 0.3)
    plt.imshow(images[i])
    plt.title(f'Class: {labels[np.argmax(titles[i],axis=0)]}')
    plt.axis("off")

# %%
model = Sequential()

model.add(Conv2D(32, (3,3), padding='same', activation='relu', input_shape=(150,150,3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
# 32개 필터, 크기3커널, 패딩 및 스트라이드 기본

model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
# 64개 필터, 크기3커널, 패딩 및 스트라이드 기본


model.add(Conv2D(128, (3,3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
# 128개 필터, 크기3커널, 패딩 및 스트라이드 기본

model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(512, (3,3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
# 256개 필터, 크기3커널, 패딩 및 스트라이드 기본

# 완전연결 신경망
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 150, 150, 32)      896
#
#  batch_normalization_5 (Batc  (None, 150, 150, 32)     128
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 75, 75, 32)       0
#  2D)
#
#  dropout_6 (Dropout)         (None, 75, 75, 32)        0
#
#  conv2d_6 (Conv2D)           (None, 75, 75, 64)        18496
#
#  batch_normalization_6 (Batc  (None, 75, 75, 64)       256
#  hNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  dropout_7 (Dropout)         (None, 37, 37, 64)        0
#
#  conv2d_7 (Conv2D)           (None, 37, 37, 128)       73856
#
#  batch_normalization_7 (Batc  (None, 37, 37, 128)      512
#  hNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 18, 18, 128)      0
#  2D)
#
#  dropout_8 (Dropout)         (None, 18, 18, 128)       0
#
#  conv2d_8 (Conv2D)           (None, 18, 18, 256)       295168
#
#  batch_normalization_8 (Batc  (None, 18, 18, 256)      1024
#  hNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 9, 9, 256)        0
#  2D)
#
#  dropout_9 (Dropout)         (None, 9, 9, 256)         0
#
#  conv2d_9 (Conv2D)           (None, 9, 9, 512)         1180160
#
#  batch_normalization_9 (Batc  (None, 9, 9, 512)        2048
#  hNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 4, 4, 512)        0
#  2D)
#
#  dropout_10 (Dropout)        (None, 4, 4, 512)         0
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dense_3 (Dense)             (None, 256)               2097408
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_5 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 3,704,138
# Trainable params: 3,702,154
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['acc'])

# %%
history1 = model.fit(train_generator,
          steps_per_epoch=train_generator.samples // train_generator.batch_size,
          validation_data=validation_generator, 
          validation_steps=validation_generator.samples // validation_generator.batch_size,
          epochs=30)
# Out:
# 500/500 [==============================] - 104s 205ms/step - loss: 1.7399 - acc: 0.4293 - val_loss: 6.0747 - val_acc: 0.1335
# Epoch 2/30
# 500/500 [==============================] - 30s 59ms/step - loss: 1.1907 - acc: 0.5931 - val_loss: 0.9748 - val_acc: 0.6895
# Epoch 3/30
# 500/500 [==============================] - 31s 61ms/step - loss: 0.9630 - acc: 0.6862 - val_loss: 0.9431 - val_acc: 0.7105
# Epoch 4/30
# 500/500 [==============================] - 30s 59ms/step - loss: 0.7871 - acc: 0.7470 - val_loss: 3.0936 - val_acc: 0.3605
# Epoch 5/30
# 500/500 [==============================] - 30s 59ms/step - loss: 0.7101 - acc: 0.7697 - val_loss: 0.7532 - val_acc: 0.7740
# Epoch 6/30
# 500/500 [==============================] - 30s 59ms/step - loss: 0.6415 - acc: 0.7944 - val_loss: 5.0717 - val_acc: 0.4145
# Epoch 7/30
# 500/500 [==============================] - 31s 61ms/step - loss: 0.5675 - acc: 0.8195 - val_loss: 5.1367 - val_acc: 0.3350
# Epoch 8/30
# 500/500 [==============================] - 29s 59ms/step - loss: 0.5227 - acc: 0.8374 - val_loss: 1.5596 - val_acc: 0.6920
# Epoch 9/30
# 500/500 [==============================] - 29s 58ms/step - loss: 0.4568 - acc: 0.8535 - val_loss: 0.6840 - val_acc: 0.8095
# Epoch 10/30
# 500/500 [==============================] - 29s 58ms/step - loss: 0.4349 - acc: 0.8679 - val_loss: 2.5408 - val_acc: 0.5425
# Epoch 11/30
# 500/500 [==============================] - 29s 58ms/step - loss: 0.4038 - acc: 0.8745 - val_loss: 0.7859 - val_acc: 0.7885
# Epoch 12/30
# 500/500 [==============================] - 30s 59ms/step - loss: 0.3597 - acc: 0.8841 - val_loss: 0.4606 - val_acc: 0.8905
# Epoch 13/30
# 500/500 [==============================] - 29s 59ms/step - loss: 0.3710 - acc: 0.8871 - val_loss: 0.3631 - val_acc: 0.8855
# Epoch 14/30
# 500/500 [==============================] - 30s 60ms/step - loss: 0.3462 - acc: 0.8929 - val_loss: 0.3193 - val_acc: 0.9160
# Epoch 15/30
# 500/500 [==============================] - 30s 59ms/step - loss: 0.2979 - acc: 0.9089 - val_loss: 0.7479 - val_acc: 0.8095
# Epoch 16/30
# 500/500 [==============================] - 29s 58ms/step - loss: 0.3084 - acc: 0.9051 - val_loss: 3.0422 - val_acc: 0.7015
# Epoch 17/30
# 500/500 [==============================] - 29s 58ms/step - loss: 0.2861 - acc: 0.9155 - val_loss: 2.5224 - val_acc: 0.5915
# Epoch 18/30
# 500/500 [==============================] - 29s 59ms/step - loss: 0.2816 - acc: 0.9185 - val_loss: 2.6046 - val_acc: 0.6765
# Epoch 19/30
# 500/500 [==============================] - 29s 58ms/step - loss: 0.2573 - acc: 0.9197 - val_loss: 0.7088 - val_acc: 0.8565
# Epoch 20/30
# 500/500 [==============================] - 29s 59ms/step - loss: 0.2416 - acc: 0.9271 - val_loss: 1.6012 - val_acc: 0.7280
# Epoch 21/30
# 500/500 [==============================] - 30s 59ms/step - loss: 0.2322 - acc: 0.9330 - val_loss: 2.6688 - val_acc: 0.6575
# Epoch 22/30
# 500/500 [==============================] - 29s 59ms/step - loss: 0.2072 - acc: 0.9377 - val_loss: 0.4580 - val_acc: 0.9040
# Epoch 23/30
# 500/500 [==============================] - 30s 59ms/step - loss: 0.2403 - acc: 0.9327 - val_loss: 0.8341 - val_acc: 0.8515
# Epoch 24/30
# 500/500 [==============================] - 30s 59ms/step - loss: 0.2057 - acc: 0.9379 - val_loss: 0.4145 - val_acc: 0.8765
# Epoch 25/30
# 500/500 [==============================] - 30s 60ms/step - loss: 0.1891 - acc: 0.9471 - val_loss: 0.5979 - val_acc: 0.8700
# Epoch 26/30
# 500/500 [==============================] - 30s 60ms/step - loss: 0.2170 - acc: 0.9360 - val_loss: 1.3768 - val_acc: 0.7470
# Epoch 27/30
# 500/500 [==============================] - 30s 60ms/step - loss: 0.1715 - acc: 0.9503 - val_loss: 0.3489 - val_acc: 0.9130
# Epoch 28/30
# 500/500 [==============================] - 30s 59ms/step - loss: 0.1623 - acc: 0.9535 - val_loss: 1.5773 - val_acc: 0.8250
# Epoch 29/30
# 500/500 [==============================] - 30s 59ms/step - loss: 0.1575 - acc: 0.9554 - val_loss: 9.1106 - val_acc: 0.5530
# Epoch 30/30
# 500/500 [==============================] - 30s 60ms/step - loss: 0.1636 - acc: 0.9526 - val_loss: 1.0190 - val_acc: 0.8170

# %%
loss, accuracy = model.evaluate(test_generator)
print(f'test accuracy is {accuracy*100}%')
# Out:
# 63/63 [==============================] - 1s 14ms/step - loss: 1.1745 - acc: 0.7940
# test accuracy is 79.40000295639038%

# %% [markdown]
# ### VGG16 미세조정 후 모델 훈련

# %%
##VGG16 fine tuning

from keras.applications import VGG16 
from tensorflow.keras import Model

vgg_model = VGG16(
    weights='imagenet', include_top=False, input_shape=(150, 150, 3)
)

# %%
# Freeze four convolution blocks
for layer in vgg_model.layers[:15]:
    layer.trainable = False
# Make sure you have frozen the correct layers
for i, layer in enumerate(vgg_model.layers):
    print(i, layer.name, layer.trainable)
# Out:
# 0 input_1 False
# 1 block1_conv1 False
# 2 block1_conv2 False
# 3 block1_pool False
# 4 block2_conv1 False
# 5 block2_conv2 False
# 6 block2_pool False
# 7 block3_conv1 False
# 8 block3_conv2 False
# 9 block3_conv3 False
# 10 block3_pool False
# 11 block4_conv1 False
# 12 block4_conv2 False
# 13 block4_conv3 False
# 14 block4_pool False
# 15 block5_conv1 True
# 16 block5_conv2 True
# 17 block5_conv3 True
# 18 block5_pool True

# %%
vgg_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 7,079,424
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %%
x = vgg_model.output
x = Flatten()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(256, activation='relu')(x)
x = Dense(10, activation='softmax')(x)
transfer_model = Model(inputs=vgg_model.input, outputs=x)

# %%
transfer_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  flatten_2 (Flatten)         (None, 8192)              0
#
#  dense_6 (Dense)             (None, 512)               4194816
#
#  dropout_12 (Dropout)        (None, 512)               0
#
#  dense_7 (Dense)             (None, 256)               131328
#
#  dense_8 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 19,043,402
# Trainable params: 11,408,138
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %%
transfer_model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['acc'])

# %%
history2 = model.fit(train_generator,
          steps_per_epoch=train_generator.samples // train_generator.batch_size,
          validation_data=validation_generator, 
          validation_steps=validation_generator.samples // validation_generator.batch_size,
          epochs=30)
# Out:
# Epoch 1/30
# 500/500 [==============================] - 30s 59ms/step - loss: 0.1692 - acc: 0.9530 - val_loss: 0.7627 - val_acc: 0.8305
# Epoch 2/30
# 500/500 [==============================] - 31s 61ms/step - loss: 0.1594 - acc: 0.9539 - val_loss: 0.6093 - val_acc: 0.8665
# Epoch 3/30
# 500/500 [==============================] - 30s 60ms/step - loss: 0.1661 - acc: 0.9544 - val_loss: 0.4348 - val_acc: 0.8950
# Epoch 4/30
# 500/500 [==============================] - 31s 61ms/step - loss: 0.1352 - acc: 0.9619 - val_loss: 2.4820 - val_acc: 0.7480
# Epoch 5/30
# 500/500 [==============================] - 30s 61ms/step - loss: 0.1279 - acc: 0.9613 - val_loss: 0.6316 - val_acc: 0.8725
# Epoch 6/30
# 500/500 [==============================] - 30s 60ms/step - loss: 0.1294 - acc: 0.9645 - val_loss: 1.5955 - val_acc: 0.7785
# Epoch 7/30
# 500/500 [==============================] - 30s 59ms/step - loss: 0.1580 - acc: 0.9579 - val_loss: 0.7701 - val_acc: 0.8505
# Epoch 8/30
# 500/500 [==============================] - 30s 60ms/step - loss: 0.1215 - acc: 0.9643 - val_loss: 3.2453 - val_acc: 0.7715
# Epoch 9/30
# 500/500 [==============================] - 31s 62ms/step - loss: 0.1539 - acc: 0.9601 - val_loss: 0.5339 - val_acc: 0.8930
# Epoch 10/30
# 500/500 [==============================] - 30s 60ms/step - loss: 0.1300 - acc: 0.9620 - val_loss: 1.7159 - val_acc: 0.7750
# Epoch 11/30
# 500/500 [==============================] - 30s 60ms/step - loss: 0.1210 - acc: 0.9679 - val_loss: 0.6029 - val_acc: 0.8595
# Epoch 12/30
# 500/500 [==============================] - 30s 60ms/step - loss: 0.1204 - acc: 0.9654 - val_loss: 0.8569 - val_acc: 0.8535
# Epoch 13/30
# 500/500 [==============================] - 30s 59ms/step - loss: 0.1133 - acc: 0.9676 - val_loss: 1.1511 - val_acc: 0.7685
# Epoch 14/30
# 500/500 [==============================] - 30s 60ms/step - loss: 0.1586 - acc: 0.9601 - val_loss: 3.2324 - val_acc: 0.6550
# Epoch 15/30
# 500/500 [==============================] - 30s 61ms/step - loss: 0.1195 - acc: 0.9651 - val_loss: 0.6832 - val_acc: 0.8800
# Epoch 16/30
# 500/500 [==============================] - 31s 61ms/step - loss: 0.1074 - acc: 0.9716 - val_loss: 1.4902 - val_acc: 0.7870
# Epoch 17/30
# 500/500 [==============================] - 30s 61ms/step - loss: 0.1090 - acc: 0.9699 - val_loss: 5.3750 - val_acc: 0.7350
# Epoch 18/30
# 500/500 [==============================] - 30s 61ms/step - loss: 0.1185 - acc: 0.9679 - val_loss: 0.4708 - val_acc: 0.9240
# Epoch 19/30
# 500/500 [==============================] - 30s 61ms/step - loss: 0.1036 - acc: 0.9740 - val_loss: 0.5387 - val_acc: 0.9090
# Epoch 20/30
# 500/500 [==============================] - 30s 59ms/step - loss: 0.1169 - acc: 0.9706 - val_loss: 0.5657 - val_acc: 0.8910
# Epoch 21/30
# 500/500 [==============================] - 30s 59ms/step - loss: 0.0972 - acc: 0.9749 - val_loss: 0.8709 - val_acc: 0.8790
# Epoch 22/30
# 500/500 [==============================] - 30s 59ms/step - loss: 0.1001 - acc: 0.9712 - val_loss: 1.0897 - val_acc: 0.8350
# Epoch 23/30
# 500/500 [==============================] - 31s 61ms/step - loss: 0.0910 - acc: 0.9719 - val_loss: 1.5208 - val_acc: 0.7670
# Epoch 24/30
# 500/500 [==============================] - 30s 60ms/step - loss: 0.0793 - acc: 0.9776 - val_loss: 0.6306 - val_acc: 0.9020
# Epoch 25/30
# 500/500 [==============================] - 30s 59ms/step - loss: 0.0972 - acc: 0.9741 - val_loss: 0.3347 - val_acc: 0.9255
# Epoch 26/30
# 500/500 [==============================] - 30s 61ms/step - loss: 0.1094 - acc: 0.9726 - val_loss: 1.0578 - val_acc: 0.8140
# Epoch 27/30
# 500/500 [==============================] - 30s 60ms/step - loss: 0.1049 - acc: 0.9714 - val_loss: 0.3807 - val_acc: 0.9305
# Epoch 28/30
# 500/500 [==============================] - 30s 59ms/step - loss: 0.1051 - acc: 0.9726 - val_loss: 0.2071 - val_acc: 0.9600
# Epoch 29/30
# 500/500 [==============================] - 30s 61ms/step - loss: 0.0865 - acc: 0.9776 - val_loss: 1.2956 - val_acc: 0.7940
# Epoch 30/30
# 500/500 [==============================] - 30s 60ms/step - loss: 0.0865 - acc: 0.9761 - val_loss: 0.2512 - val_acc: 0.9445

# %%
loss, accuracy = model.evaluate(test_generator)
print(f'test accuracy is {accuracy*100}%')
# Out:
# 63/63 [==============================] - 1s 16ms/step - loss: 0.3961 - acc: 0.9270
# test accuracy is 92.69999861717224%
